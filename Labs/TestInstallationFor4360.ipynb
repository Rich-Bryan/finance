# %% [markdown]
# # Checking Your Jupyter Notebook Environment

# %%
import warnings
#warnings.filterwarnings('ignore')

# %%
import sys
import os
import platform 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# run the following if it is the first time
try:
    import plotly
except:
    os.system("pip install plotly")

# %%
# run the following if it is the first time
try:
    import dash
except:
    os.system("pip install dash --user")

# %%
try:
    import yfinance
except:
    os.system("pip install yfinance")

# %%
try:
    import yahoofinancials
except:
    os.system("pip install yahoofinancials")

# %%
import plotly
import dash
import yfinance
import yahoofinancials

# %%
print(sys.executable)
print(platform.python_version())
print(pd.__version__)
print(np.__version__)
print(plotly.__version__)
print(dash.__version__)
print(yfinance.__version__)
# Out:
# C:\Users\tomso\anaconda3\python.exe
# 3.11.4
# 1.5.3
# 1.24.3
# 5.9.0
# 2.13.0
# 0.2.28

# %% [markdown]
# # check datasets available

# %%
# Common datasets from seaborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# **Iris Dataset is the "Hello World" dataset in Machine Learning**

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Testing yfinance

# %%
import yfinance as yf
import option
import utils

# %%
ticker = 'MSFT'
stock = yf.Ticker(ticker)

# %%
df = stock.history(start = '2003-01-01', end = '2023-08-01', interval = '1d')
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2003-01-02 00:00:00-05:00   16.244961   16.695347   16.061700   16.686029
# 2003-01-03 00:00:00-05:00   16.645643   16.710871   16.425110   16.707766
# 2003-01-06 00:00:00-05:00   16.779209   17.155048   16.710874   17.012167
# 2003-01-07 00:00:00-05:00   17.058756   17.397322   16.984210   17.332094
# 2003-01-08 00:00:00-05:00   17.198535   17.254445   16.807166   16.847546
# ...                               ...         ...         ...         ...
# 2023-07-25 00:00:00-04:00  346.376615  351.146545  344.340947  350.238464
# 2023-07-26 00:00:00-04:00  340.718626  343.941812  332.406208  337.056366
# 2023-07-27 00:00:00-04:00  339.760660  340.608840  328.354786  330.021271
# 2023-07-28 00:00:00-04:00  332.965039  339.291640  332.466095  337.655090
# 2023-07-31 00:00:00-04:00  336.208184  336.986535  332.655677  335.210297
#
#                              Volume  Dividends  Stock Splits
# Date
# 2003-01-02 00:00:00-05:00  67025200        0.0           0.0
# 2003-01-03 00:00:00-05:00  55546800        0.0           0.0
# 2003-01-06 00:00:00-05:00  59456200        0.0           0.0
# 2003-01-07 00:00:00-05:00  80517400        0.0           0.0
# 2003-01-08 00:00:00-05:00  64566000        0.0           0.0
# ...                             ...        ...           ...
# 2023-07-25 00:00:00-04:00  41637700        0.0           0.0
# 2023-07-26 00:00:00-04:00  58383700        0.0           0.0
# 2023-07-27 00:00:00-04:00  39635300        0.0           0.0
# 2023-07-28 00:00:00-04:00  28484900        0.0           0.0
# 2023-07-31 00:00:00-04:00  25446000        0.0           0.0
#
# [5179 rows x 7 columns]

# %% [markdown]
# ***Let's focus on the last 2 years data***

# %%
df = df[-252*2:]
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-07-29 00:00:00-04:00  280.609302  282.942489  280.452446  280.864197
# 2021-07-30 00:00:00-04:00  279.560376  281.021056  278.325152  279.305481
# 2021-08-02 00:00:00-04:00  280.726939  281.128878  278.158483  279.217255
# 2021-08-03 00:00:00-04:00  279.805474  281.579867  278.413394  281.472015
# 2021-08-04 00:00:00-04:00  280.589750  281.932796  279.050627  280.874054
# ...                               ...         ...         ...         ...
# 2023-07-25 00:00:00-04:00  346.376615  351.146545  344.340947  350.238464
# 2023-07-26 00:00:00-04:00  340.718626  343.941812  332.406208  337.056366
# 2023-07-27 00:00:00-04:00  339.760660  340.608840  328.354786  330.021271
# 2023-07-28 00:00:00-04:00  332.965039  339.291640  332.466095  337.655090
# 2023-07-31 00:00:00-04:00  336.208184  336.986535  332.655677  335.210297
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-07-29 00:00:00-04:00  18168300        0.0           0.0
# 2021-07-30 00:00:00-04:00  20944800        0.0           0.0
# 2021-08-02 00:00:00-04:00  16267400        0.0           0.0
# 2021-08-03 00:00:00-04:00  17879000        0.0           0.0
# 2021-08-04 00:00:00-04:00  16191300        0.0           0.0
# ...                             ...        ...           ...
# 2023-07-25 00:00:00-04:00  41637700        0.0           0.0
# 2023-07-26 00:00:00-04:00  58383700        0.0           0.0
# 2023-07-27 00:00:00-04:00  39635300        0.0           0.0
# 2023-07-28 00:00:00-04:00  28484900        0.0           0.0
# 2023-07-31 00:00:00-04:00  25446000        0.0           0.0
#
# [504 rows x 7 columns]

# %% [markdown]
# ***Let's do some data visualization***

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=go.Scatter(x=df.index,y=df['Close'], mode='lines'))
fig.show()

# %% [markdown]
# ***Add Volume to the chart***

# %%
from plotly.subplots import make_subplots

# %%
fig2 = make_subplots(specs=[[{"secondary_y": True}]])
fig2.add_trace(go.Scatter(x=df.index,y=df['Close'],name='Price'),secondary_y=False)
fig2.add_trace(go.Bar(x=df.index,y=df['Volume'],name='Volume'),secondary_y=True)
fig2.show()
# Out:
# <div>                            <div id="e3fef551-0453-42e9-b32c-2af642168eb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3fef551-0453-42e9-b32c-2af642168eb6")) {                    Plotly.newPlot(                        "e3fef551-0453-42e9-b32c-2af642168eb6",                        [{"name":"Price","x":["2021-07-29T00:00:00-04:00","2021-07-30T00:00:00-04:00","2021-08-02T00:00:00-04:00","2021-08-03T00:00:00-04:00","2021-08-04T00:00:00-04:00","2021-08-05T00:00:00-04:00","2021-08-06T00:00:00-04:00","2021-08-09T00:00:00-04:00","2021-08-10T00:00:00-04:00","2021-08-11T00:00:00-04:00","2021-08-12T00:00:00-04:00","2021-08-13T00:00:00-04:00","2021-08-16T00:00:00-04:00","2021-08-17T00:00:00-04:00","2021-08-18T00:00:00-04:00","2021-08-19T00:00:00-04:00","2021-08-20T00:00:00-04:00","2021-08-23T00:00:00-04:00","2021-08-24T00:00:00-04:00","2021-08-25T00:00:00-04:00","2021-08-26T00:00:00-04:00","2021-08-27T00:00:00-04:00","2021-08-30T00:00:00-04:00","2021-08-31T00:00:00-04:00","2021-09-01T00:00:00-04:00","2021-09-02T00:00:00-04:00","2021-09-03T00:00:00-04:00","2021-09-07T00:00:00-04:00","2021-09-08T00:00:00-04:00","2021-09-09T00:00:00-04:00","2021-09-10T00:00:00-04:00","2021-09-13T00:00:00-04:00","2021-09-14T00:00:00-04:00","2021-09-15T00:00:00-04:00","2021-09-16T00:00:00-04:00","2021-09-17T00:00:00-04:00","2021-09-20T00:00:00-04:00","2021-09-21T00:00:00-04:00","2021-09-22T00:00:00-04:00","2021-09-23T00:00:00-04:00","2021-09-24T00:00:00-04:00","2021-09-27T00:00:00-04:00","2021-09-28T00:00:00-04:00","2021-09-29T00:00:00-04:00","2021-09-30T00:00:00-04:00","2021-10-01T00:00:00-04:00","2021-10-04T00:00:00-04:00","2021-10-05T00:00:00-04:00","2021-10-06T00:00:00-04:00","2021-10-07T00:00:00-04:00","2021-10-08T00:00:00-04:00","2021-10-11T00:00:00-04:00","2021-10-12T00:00:00-04:00","2021-10-13T00:00:00-04:00","2021-10-14T00:00:00-04:00","2021-10-15T00:00:00-04:00","2021-10-18T00:00:00-04:00","2021-10-19T00:00:00-04:00","2021-10-20T00:00:00-04:00","2021-10-21T00:00:00-04:00","2021-10-22T00:00:00-04:00","2021-10-25T00:00:00-04:00","2021-10-26T00:00:00-04:00","2021-10-27T00:00:00-04:00","2021-10-28T00:00:00-04:00","2021-10-29T00:00:00-04:00","2021-11-01T00:00:00-04:00","2021-11-02T00:00:00-04:00","2021-11-03T00:00:00-04:00","2021-11-04T00:00:00-04:00","2021-11-05T00:00:00-04:00","2021-11-08T00:00:00-05:00","2021-11-09T00:00:00-05:00","2021-11-10T00:00:00-05:00","2021-11-11T00:00:00-05:00","2021-11-12T00:00:00-05:00","2021-11-15T00:00:00-05:00","2021-11-16T00:00:00-05:00","2021-11-17T00:00:00-05:00","2021-11-18T00:00:00-05:00","2021-11-19T00:00:00-05:00","2021-11-22T00:00:00-05:00","2021-11-23T00:00:00-05:00","2021-11-24T00:00:00-05:00","2021-11-26T00:00:00-05:00","2021-11-29T00:00:00-05:00","2021-11-30T00:00:00-05:00","2021-12-01T00:00:00-05:00","2021-12-02T00:00:00-05:00","2021-12-03T00:00:00-05:00","2021-12-06T00:00:00-05:00","2021-12-07T00:00:00-05:00","2021-12-08T00:00:00-05:00","2021-12-09T00:00:00-05:00","2021-12-10T00:00:00-05:00","2021-12-13T00:00:00-05:00","2021-12-14T00:00:00-05:00","2021-12-15T00:00:00-05:00","2021-12-16T00:00:00-05:00","2021-12-17T00:00:00-05:00","2021-12-20T00:00:00-05:00","2021-12-21T00:00:00-05:00","2021-12-22T00:00:00-05:00","2021-12-23T00:00:00-05:00","2021-12-27T00:00:00-05:00","2021-12-28T00:00:00-05:00","2021-12-29T00:00:00-05:00","2021-12-30T00:00:00-05:00","2021-12-31T00:00:00-05:00","2022-01-03T00:00:00-05:00","2022-01-04T00:00:00-05:00","2022-01-05T00:00:00-05:00","2022-01-06T00:00:00-05:00","2022-01-07T00:00:00-05:00","2022-01-10T00:00:00-05:00","2022-01-11T00:00:00-05:00","2022-01-12T00:00:00-05:00","2022-01-13T00:00:00-05:00","2022-01-14T00:00:00-05:00","2022-01-18T00:00:00-05:00","2022-01-19T00:00:00-05:00","2022-01-20T00:00:00-05:00","2022-01-21T00:00:00-05:00","202 ...

# %% [markdown]
# ### Make sure we can import our course library

# %%
import option

# %%
import utils

# %%
opt = option.Option()

# %%
print(opt.verbose, opt.start_date, opt.end_date, opt.tickers)
# Out:
# False None None None

# %%
ticker = 'MSFT'
yfinancials = utils.MyYahooFinancials(ticker)
print(f"Getting Financial Data for {ticker}")
print(f"{ticker} Long Term Debt is {yfinancials.get_long_term_debt()}")
# Out:
# Getting Financial Data for MSFT
# MSFT Long Term Debt is 59578000000.0
